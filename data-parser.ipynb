# %%
import os
import numpy as np
from PIL import Image

root = "./"
raw = os.path.join(root, "raw")
directories = ['front', 'anim_front', 'back', 'icon', 'footprint']

pokemon_list = [name for name in os.listdir(raw)
    if os.path.isdir(os.path.join(raw, name))]

# %%
def instantiate_directories():
    for directory in directories:
        path = os.path.join(root, directory)
        if os.path.exists(path) == False:
            print(path, 'folder created.')
            os.mkdir(path)
            
def parse_front():
    for pokemon in pokemon_list:
        input_path = os.path.join(raw, pokemon, 'front.png')
        output_path = os.path.join(root, 'front', pokemon + ".png")
        
        if os.path.exists(input_path) and os.path.exists(output_path) == False:        
            im = Image.open(input_path)
            
            print(output_path, 'image parsed.')
            im.save(output_path)
        
def parse_anim_front():
    for pokemon in pokemon_list:
        input_path = os.path.join(raw, pokemon, 'anim_front.png')
        output_path = os.path.join(root, 'anim_front', pokemon + ".png")
        
        if os.path.exists(input_path) and os.path.exists(output_path) == False:        
            im = Image.open(input_path)
            
            print(output_path, 'image parsed.')
            im.save(output_path)
                
def parse_back():
    for pokemon in pokemon_list:
        front_path = os.path.join(raw, pokemon, 'front.png')
        back_path = os.path.join(raw, pokemon, 'back.png')
        output_path = os.path.join(root, 'back', pokemon + ".png")
        
        if os.path.exists(front_path) and os.path.exists(back_path) and os.path.exists(output_path) == False:        
            front_image = Image.open(front_path)
            back_image = Image.open(back_path)
            
            front_raw_palette = front_image.getpalette()
            if int(len(front_raw_palette) / 3) == 16:
                front_palette = np.array(front_raw_palette,dtype=np.uint8).reshape((int(len(front_raw_palette) / 3),3))
                back_image.putpalette(front_palette)

            print(output_path, 'image parsed.')
            back_image.save(output_path)
                
def parse_icon():
    for pokemon in pokemon_list:
        input_path = os.path.join(raw, pokemon, 'icon.png')
        output_path = os.path.join(root, 'icon', pokemon + ".png")
        
        if os.path.exists(input_path) and os.path.exists(output_path) == False:        
            im = Image.open(input_path)
            
            print(output_path, 'image parsed.')
            im.save(output_path)
            
def parse_footprint():
    for pokemon in pokemon_list:
        input_path = os.path.join(raw, pokemon, 'footprint.png')
        output_path = os.path.join(root, 'footprint', pokemon + ".png")
        
        if os.path.exists(input_path) and os.path.exists(output_path) == False:        
            im = Image.open(input_path)
            
            print(output_path, 'image parsed.')
            im.save(output_path)

# %%
instantiate_directories()
parse_front()
parse_anim_front()
parse_back()
parse_icon()
parse_footprint()
# Out:
# ./icon\abomasnow.png image parsed.
# ./icon\abra.png image parsed.
# ./icon\absol.png image parsed.
# ./icon\accelgor.png image parsed.
# ./icon\aegislash.png image parsed.
# ./icon\aerodactyl.png image parsed.
# ./icon\aggron.png image parsed.
# ./icon\aipom.png image parsed.
# ./icon\alakazam.png image parsed.
# ./icon\alolan_diglett.png image parsed.
# ./icon\alolan_dugtrio.png image parsed.
# ./icon\alolan_exeggutor.png image parsed.
# ./icon\alolan_geodude.png image parsed.
# ./icon\alolan_golem.png image parsed.
# ./icon\alolan_graveler.png image parsed.
# ./icon\alolan_grimer.png image parsed.
# ./icon\alolan_marowak.png image parsed.
# ./icon\alolan_meowth.png image parsed.
# ./icon\alolan_muk.png image parsed.
# ./icon\alolan_ninetales.png image parsed.
# ./icon\alolan_persian.png image parsed.
# ./icon\alolan_raichu.png image parsed.
# ./icon\alolan_raticate.png image parsed.
# ./icon\alolan_rattata.png image parsed.
# ./icon\alolan_sandshrew.png image parsed.
# ./icon\alolan_sandslash.png image parsed.
# ./icon\alolan_vulpix.png image parsed.
# ./icon\alomomola.png image parsed.
# ./icon\altaria.png image parsed.
# ./icon\amaura.png image parsed.
# ./icon\ambipom.png image parsed.
# ./icon\amoonguss.png image parsed.
# ./icon\ampharos.png image parsed.
# ./icon\anorith.png image parsed.
# ./icon\araquanid.png image parsed.
# ./icon\arbok.png image parsed.
# ./icon\arcanine.png image parsed.
# ./icon\arceus.png image parsed.
# ./icon\archen.png image parsed.
# ./icon\archeops.png image parsed.
# ./icon\ariados.png image parsed.
# ./icon\armaldo.png image parsed.
# ./icon\aromatisse.png image parsed.
# ./icon\aron.png image parsed.
# ./icon\articuno.png image parsed.
# ./icon\audino.png image parsed.
# ./icon\aurorus.png image parsed.
# ./icon\avalugg.png image parsed.
# ./icon\axew.png image parsed.
# ./icon\azelf.png image parsed.
# ./icon\azumarill.png image parsed.
# ./icon\azurill.png image parsed.
# ./icon\bagon.png image parsed.
# ./icon\baltoy.png image parsed.
# ./icon\banette.png image parsed.
# ./icon\barbaracle.png image parsed.
# ./icon\barboach.png image parsed.
# ./icon\basculin.png image parsed.
# ./icon\bastiodon.png image parsed.
# ./icon\bayleef.png image parsed.
# ./icon\beartic.png image parsed.
# ./icon\beautifly.png image parsed.
# ./icon\beedrill.png image parsed.
# ./icon\beheeyem.png image parsed.
# ./icon\beldum.png image parsed.
# ./icon\bellossom.png image parsed.
# ./icon\bellsprout.png image parsed.
# ./icon\bergmite.png image parsed.
# ./icon\bewear.png image parsed.
# ./icon\bibarel.png image parsed.
# ./icon\bidoof.png image parsed.
# ./icon\binacle.png image parsed.
# ./icon\bisharp.png image parsed.
# ./icon\blacephalon.png image parsed.
# ./icon\blastoise.png image parsed.
# ./icon\blaziken.png image parsed.
# ./icon\blissey.png image parsed.
# ./icon\blitzle.png image parsed.
# ./icon\boldore.png image parsed.
# ./icon\bonsly.png image parsed.
# ./icon\bouffalant.png image parsed.
# ./icon\bounsweet.png image parsed.
# ./icon\braixen.png image parsed.
# ./icon\braviary.png image parsed.
# ./icon\breloom.png image parsed.
# ./icon\brionne.png image parsed.
# ./icon\bronzong.png image parsed.
# ./icon\bronzor.png image parsed.
# ./icon\bruxish.png image parsed.
# ./icon\budew.png image parsed.
# ./icon\buizel.png image parsed.
# ./icon\bulbasaur.png image parsed.
# ./icon\buneary.png image parsed.
# ./icon\bunnelby.png image parsed.
# ./icon\burmy.png image parsed.
# ./icon\butterfree.png image parsed.
# ./icon\buzzwole.png image parsed.
# ./icon\cacnea.png image parsed.
# ./icon\cacturne.png image parsed.
# ./icon\camerupt.png image parsed.
# ./icon\carbink.png image parsed.
# ./icon\carnivine.png image parsed.
# ./icon\carracosta.png image parsed.
# ./icon\carvanha.png image parsed.
# ./icon\cascoon.png image parsed.
# ./icon\castform.png image parsed.
# ./icon\caterpie.png image parsed.
# ./icon\celebi.png image parsed.
# ./icon\celesteela.png image parsed.
# ./icon\chandelure.png image parsed.
# ./icon\chansey.png image parsed.
# ./icon\charizard.png image parsed.
# ./icon\charjabug.png image parsed.
# ./icon\charmander.png image parsed.
# ./icon\charmeleon.png image parsed.
# ./icon\chatot.png image parsed.
# ./icon\cherrim.png image parsed.
# ./icon\cherubi.png image parsed.
# ./icon\chesnaught.png image parsed.
# ./icon\chespin.png image parsed.
# ./icon\chikorita.png image parsed.
# ./icon\chimchar.png image parsed.
# ./icon\chimecho.png image parsed.
# ./icon\chinchou.png image parsed.
# ./icon\chingling.png image parsed.
# ./icon\cinccino.png image parsed.
# ./icon\clamperl.png image parsed.
# ./icon\clauncher.png image parsed.
# ./icon\clawitzer.png image parsed.
# ./icon\claydol.png image parsed.
# ./icon\clefable.png image parsed.
# ./icon\clefairy.png image parsed.
# ./icon\cleffa.png image parsed.
# ./icon\cloyster.png image parsed.
# ./icon\cobalion.png image parsed.
# ./icon\cofagrigus.png image parsed.
# ./icon\combee.png image parsed.
# ./icon\combusken.png image parsed.
# ./icon\comfey.png image parsed.
# ./icon\conkeldurr.png image parsed.
# ./icon\corphish.png image parsed.
# ./icon\corsola.png image parsed.
# ./icon\cosmoem.png image parsed.
# ./icon\cosmog.png image parsed.
# ./icon\cottonee.png image parsed.
# ./icon\crabominable.png image parsed.
# ./icon\crabrawler.png image parsed.
# ./icon\cradily.png image parsed.
# ./icon\cranidos.png image parsed.
# ./icon\crawdaunt.png image parsed.
# ./icon\cresselia.png image parsed.
# ./icon\croagunk.png image parsed.
# ./icon\crobat.png image parsed.
# ./icon\croconaw.png image parsed.
# ./icon\crustle.png image parsed.
# ./icon\cryogonal.png image parsed.
# ./icon\cubchoo.png image parsed.
# ./icon\cubone.png image parsed.
# ./icon\cutiefly.png image parsed.
# ./icon\cyndaquil.png image parsed.
# ./icon\darkrai.png image parsed.
# ./icon\darmanitan.png image parsed.
# ./icon\dartrix.png image parsed.
# ./icon\darumaka.png image parsed.
# ./icon\decidueye.png image parsed.
# ./icon\dedenne.png image parsed.
# ./icon\deerling.png image parsed.
# ./icon\deino.png image parsed.
# ./icon\delcatty.png image parsed.
# ./icon\delibird.png image parsed.
# ./icon\delphox.png image parsed.
# ./icon\deoxys.png image parsed.
# ./icon\dewgong.png image parsed.
# ./icon\dewott.png image parsed.
# ./icon\dewpider.png image parsed.
# ./icon\dhelmise.png image parsed.
# ./icon\dialga.png image parsed.
# ./icon\diancie.png image parsed.
# ./icon\diggersby.png image parsed.
# ./icon\diglett.png image parsed.
# ./icon\ditto.png image parsed.
# ./icon\dodrio.png image parsed.
# ./icon\doduo.png image parsed.
# ./icon\donphan.png image parsed.
# ./icon\doublade.png image parsed.
# ./icon\dragalge.png image parsed.
# ./icon\dragonair.png image parsed.
# ./icon\dragonite.png image parsed.
# ./icon\drampa.png image parsed.
# ./icon\drapion.png image parsed.
# ./icon\dratini.png image parsed.
# ./icon\drifblim.png image parsed.
# ./icon\drifloon.png image parsed.
# ./icon\drilbur.png image parsed.
# ./icon\drowzee.png image parsed.
# ./icon\druddigon.png image parsed.
# ./icon\ducklett.png image parsed.
# ./icon\dugtrio.png image parsed.
# ./icon\dunsparce.png image parsed.
# ./icon\duosion.png image parsed.
# ./icon\durant.png image parsed.
# ./icon\dusclops.png image parsed.
# ./icon\dusknoir.png image parsed.
# ./icon\duskull.png image parsed.
# ./icon\dustox.png image parsed.
# ./icon\dwebble.png image parsed.
# ./icon\eelektrik.png image parsed.
# ./icon\eelektross.png image parsed.
# ./icon\eevee.png image parsed.
# ./icon\egg.png image parsed.
# ./icon\ekans.png image parsed.
# ./icon\electabuzz.png image parsed.
# ./icon\electivire.png image parsed.
# ./icon\electrike.png image parsed.
# ./icon\electrode.png image parsed.
# ./icon\elekid.png image parsed.
# ./icon\elgyem.png image parsed.
# ./icon\emboar.png image parsed.
# ./icon\emolga.png image parsed.
# ./icon\empoleon.png image parsed.
# ./icon\entei.png image parsed.
# ./icon\escavalier.png image parsed.
# ./icon\espeon.png image parsed.
# ./icon\espurr.png image parsed.
# ./icon\excadrill.png image parsed.
# ./icon\exeggcute.png image parsed.
# ./icon\exeggutor.png image parsed.
# ./icon\exploud.png image parsed.
# ./icon\farfetchd.png image parsed.
# ./icon\fearow.png image parsed.
# ./icon\feebas.png image parsed.
# ./icon\fennekin.png image parsed.
# ./icon\feraligatr.png image parsed.
# ./icon\ferroseed.png image parsed.
# ./icon\ferrothorn.png image parsed.
# ./icon\finneon.png image parsed.
# ./icon\flaaffy.png image parsed.
# ./icon\flabebe.png image parsed.
# ./icon\flareon.png image parsed.
# ./icon\fletchinder.png image parsed.
# ./icon\fletchling.png image parsed.
# ./icon\floatzel.png image parsed.
# ./icon\floette.png image parsed.
# ./icon\florges.png image parsed.
# ./icon\flygon.png image parsed.
# ./icon\fomantis.png image parsed.
# ./icon\foongus.png image parsed.
# ./icon\forretress.png image parsed.
# ./icon\fraxure.png image parsed.
# ./icon\frillish.png image parsed.
# ./icon\froakie.png image parsed.
# ./icon\frogadier.png image parsed.
# ./icon\froslass.png image parsed.
# ./icon\furfrou.png image parsed.
# ./icon\furret.png image parsed.
# ./icon\gabite.png image parsed.
# ./icon\gallade.png image parsed.
# ./icon\galvantula.png image parsed.
# ./icon\garbodor.png image parsed.
# ./icon\garchomp.png image parsed.
# ./icon\gardevoir.png image parsed.
# ./icon\gastly.png image parsed.
# ./icon\gastrodon.png image parsed.
# ./icon\genesect.png image parsed.
# ./icon\gengar.png image parsed.
# ./icon\geodude.png image parsed.
# ./icon\gible.png image parsed.
# ./icon\gigalith.png image parsed.
# ./icon\girafarig.png image parsed.
# ./icon\giratina.png image parsed.
# ./icon\glaceon.png image parsed.
# ./icon\glalie.png image parsed.
# ./icon\glameow.png image parsed.
# ./icon\gligar.png image parsed.
# ./icon\gliscor.png image parsed.
# ./icon\gloom.png image parsed.
# ./icon\gogoat.png image parsed.
# ./icon\golbat.png image parsed.
# ./icon\goldeen.png image parsed.
# ./icon\golduck.png image parsed.
# ./icon\golem.png image parsed.
# ./icon\golett.png image parsed.
# ./icon\golisopod.png image parsed.
# ./icon\golurk.png image parsed.
# ./icon\goodra.png image parsed.
# ./icon\goomy.png image parsed.
# ./icon\gorebyss.png image parsed.
# ./icon\gothita.png image parsed.
# ./icon\gothitelle.png image parsed.
# ./icon\gothorita.png image parsed.
# ./icon\gourgeist.png image parsed.
# ./icon\granbull.png image parsed.
# ./icon\graveler.png image parsed.
# ./icon\greninja.png image parsed.
# ./icon\grimer.png image parsed.
# ./icon\grotle.png image parsed.
# ./icon\groudon.png image parsed.
# ./icon\grovyle.png image parsed.
# ./icon\growlithe.png image parsed.
# ./icon\grubbin.png image parsed.
# ./icon\grumpig.png image parsed.
# ./icon\gulpin.png image parsed.
# ./icon\gumshoos.png image parsed.
# ./icon\gurdurr.png image parsed.
# ./icon\guzzlord.png image parsed.
# ./icon\gyarados.png image parsed.
# ./icon\hakamo_o.png image parsed.
# ./icon\happiny.png image parsed.
# ./icon\hariyama.png image parsed.
# ./icon\haunter.png image parsed.
# ./icon\hawlucha.png image parsed.
# ./icon\haxorus.png image parsed.
# ./icon\heatmor.png image parsed.
# ./icon\heatran.png image parsed.
# ./icon\heliolisk.png image parsed.
# ./icon\helioptile.png image parsed.
# ./icon\heracross.png image parsed.
# ./icon\herdier.png image parsed.
# ./icon\hippopotas.png image parsed.
# ./icon\hippowdon.png image parsed.
# ./icon\hitmonchan.png image parsed.
# ./icon\hitmonlee.png image parsed.
# ./icon\hitmontop.png image parsed.
# ./icon\honchkrow.png image parsed.
# ./icon\honedge.png image parsed.
# ./icon\hoopa.png image parsed.
# ./icon\hoothoot.png image parsed.
# ./icon\hoppip.png image parsed.
# ./icon\horsea.png image parsed.
# ./icon\houndoom.png image parsed.
# ./icon\houndour.png image parsed.
# ./icon\ho_oh.png image parsed.
# ./icon\huntail.png image parsed.
# ./icon\hydreigon.png image parsed.
# ./icon\hypno.png image parsed.
# ./icon\igglybuff.png image parsed.
# ./icon\illumise.png image parsed.
# ./icon\incineroar.png image parsed.
# ./icon\infernape.png image parsed.
# ./icon\inkay.png image parsed.
# ./icon\ivysaur.png image parsed.
# ./icon\jangmo_o.png image parsed.
# ./icon\jellicent.png image parsed.
# ./icon\jigglypuff.png image parsed.
# ./icon\jirachi.png image parsed.
# ./icon\jolteon.png image parsed.
# ./icon\joltik.png image parsed.
# ./icon\jumpluff.png image parsed.
# ./icon\jynx.png image parsed.
# ./icon\kabuto.png image parsed.
# ./icon\kabutops.png image parsed.
# ./icon\kadabra.png image parsed.
# ./icon\kakuna.png image parsed.
# ./icon\kangaskhan.png image parsed.
# ./icon\karrablast.png image parsed.
# ./icon\kartana.png image parsed.
# ./icon\kecleon.png image parsed.
# ./icon\keldeo.png image parsed.
# ./icon\kingdra.png image parsed.
# ./icon\kingler.png image parsed.
# ./icon\kirlia.png image parsed.
# ./icon\klang.png image parsed.
# ./icon\klefki.png image parsed.
# ./icon\klink.png image parsed.
# ./icon\klinklang.png image parsed.
# ./icon\koffing.png image parsed.
# ./icon\komala.png image parsed.
# ./icon\kommo_o.png image parsed.
# ./icon\krabby.png image parsed.
# ./icon\kricketot.png image parsed.
# ./icon\kricketune.png image parsed.
# ./icon\krokorok.png image parsed.
# ./icon\krookodile.png image parsed.
# ./icon\kyogre.png image parsed.
# ./icon\kyurem.png image parsed.
# ./icon\lairon.png image parsed.
# ./icon\lampent.png image parsed.
# ./icon\landorus.png image parsed.
# ./icon\lanturn.png image parsed.
# ./icon\lapras.png image parsed.
# ./icon\larvesta.png image parsed.
# ./icon\larvitar.png image parsed.
# ./icon\latias.png image parsed.
# ./icon\latios.png image parsed.
# ./icon\leafeon.png image parsed.
# ./icon\leavanny.png image parsed.
# ./icon\ledian.png image parsed.
# ./icon\ledyba.png image parsed.
# ./icon\lickilicky.png image parsed.
# ./icon\lickitung.png image parsed.
# ./icon\liepard.png image parsed.
# ./icon\lileep.png image parsed.
# ./icon\lilligant.png image parsed.
# ./icon\lillipup.png image parsed.
# ./icon\linoone.png image parsed.
# ./icon\litleo.png image parsed.
# ./icon\litten.png image parsed.
# ./icon\litwick.png image parsed.
# ./icon\lombre.png image parsed.
# ./icon\lopunny.png image parsed.
# ./icon\lotad.png image parsed.
# ./icon\loudred.png image parsed.
# ./icon\lucario.png image parsed.
# ./icon\ludicolo.png image parsed.
# ./icon\lugia.png image parsed.
# ./icon\lumineon.png image parsed.
# ./icon\lunala.png image parsed.
# ./icon\lunatone.png image parsed.
# ./icon\lurantis.png image parsed.
# ./icon\luvdisc.png image parsed.
# ./icon\luxio.png image parsed.
# ./icon\luxray.png image parsed.
# ./icon\lycanroc.png image parsed.
# ./icon\machamp.png image parsed.
# ./icon\machoke.png image parsed.
# ./icon\machop.png image parsed.
# ./icon\magby.png image parsed.
# ./icon\magcargo.png image parsed.
# ./icon\magearna.png image parsed.
# ./icon\magikarp.png image parsed.
# ./icon\magmar.png image parsed.
# ./icon\magmortar.png image parsed.
# ./icon\magnemite.png image parsed.
# ./icon\magneton.png image parsed.
# ./icon\magnezone.png image parsed.
# ./icon\makuhita.png image parsed.
# ./icon\malamar.png image parsed.
# ./icon\mamoswine.png image parsed.
# ./icon\manaphy.png image parsed.
# ./icon\mandibuzz.png image parsed.
# ./icon\manectric.png image parsed.
# ./icon\mankey.png image parsed.
# ./icon\mantine.png image parsed.
# ./icon\mantyke.png image parsed.
# ./icon\maractus.png image parsed.
# ./icon\mareanie.png image parsed.
# ./icon\mareep.png image parsed.
# ./icon\marill.png image parsed.
# ./icon\marowak.png image parsed.
# ./icon\marshadow.png image parsed.
# ./icon\marshtomp.png image parsed.
# ./icon\masquerain.png image parsed.
# ./icon\mawile.png image parsed.
# ./icon\medicham.png image parsed.
# ./icon\meditite.png image parsed.
# ./icon\meganium.png image parsed.
# ./icon\mega_abomasnow.png image parsed.
# ./icon\mega_absol.png image parsed.
# ./icon\mega_aerodactyl.png image parsed.
# ./icon\mega_aggron.png image parsed.
# ./icon\mega_alakazam.png image parsed.
# ./icon\mega_altaria.png image parsed.
# ./icon\mega_ampharos.png image parsed.
# ./icon\mega_audino.png image parsed.
# ./icon\mega_banette.png image parsed.
# ./icon\mega_beedrill.png image parsed.
# ./icon\mega_blastoise.png image parsed.
# ./icon\mega_blaziken.png image parsed.
# ./icon\mega_camerupt.png image parsed.
# ./icon\mega_charizard_x.png image parsed.
# ./icon\mega_charizard_y.png image parsed.
# ./icon\mega_diancie.png image parsed.
# ./icon\mega_gallade.png image parsed.
# ./icon\mega_garchomp.png image parsed.
# ./icon\mega_gardevoir.png image parsed.
# ./icon\mega_gengar.png image parsed.
# ./icon\mega_glalie.png image parsed.
# ./icon\mega_gyarados.png image parsed.
# ./icon\mega_heracross.png image parsed.
# ./icon\mega_houndoom.png image parsed.
# ./icon\mega_kangaskhan.png image parsed.
# ./icon\mega_latias.png image parsed.
# ./icon\mega_latios.png image parsed.
# ./icon\mega_lopunny.png image parsed.
# ./icon\mega_lucario.png image parsed.
# ./icon\mega_manectric.png image parsed.
# ./icon\mega_mawile.png image parsed.
# ./icon\mega_medicham.png image parsed.
# ./icon\mega_metagross.png image parsed.
# ./icon\mega_mewtwo_x.png image parsed.
# ./icon\mega_mewtwo_y.png image parsed.
# ./icon\mega_pidgeot.png image parsed.
# ./icon\mega_pinsir.png image parsed.
# ./icon\mega_rayquaza.png image parsed.
# ./icon\mega_sableye.png image parsed.
# ./icon\mega_salamence.png image parsed.
# ./icon\mega_sceptile.png image parsed.
# ./icon\mega_scizor.png image parsed.
# ./icon\mega_sharpedo.png image parsed.
# ./icon\mega_slowbro.png image parsed.
# ./icon\mega_steelix.png image parsed.
# ./icon\mega_swampert.png image parsed.
# ./icon\mega_tyranitar.png image parsed.
# ./icon\mega_venusaur.png image parsed.
# ./icon\melmetal.png image parsed.
# ./icon\meloetta.png image parsed.
# ./icon\meltan.png image parsed.
# ./icon\meowstic.png image parsed.
# ./icon\meowth.png image parsed.
# ./icon\mesprit.png image parsed.
# ./icon\metagross.png image parsed.
# ./icon\metang.png image parsed.
# ./icon\metapod.png image parsed.
# ./icon\mew.png image parsed.
# ./icon\mewtwo.png image parsed.
# ./icon\mienfoo.png image parsed.
# ./icon\mienshao.png image parsed.
# ./icon\mightyena.png image parsed.
# ./icon\milotic.png image parsed.
# ./icon\miltank.png image parsed.
# ./icon\mime_jr.png image parsed.
# ./icon\mimikyu.png image parsed.
# ./icon\minccino.png image parsed.
# ./icon\minior.png image parsed.
# ./icon\minun.png image parsed.
# ./icon\misdreavus.png image parsed.
# ./icon\mismagius.png image parsed.
# ./icon\moltres.png image parsed.
# ./icon\monferno.png image parsed.
# ./icon\morelull.png image parsed.
# ./icon\mothim.png image parsed.
# ./icon\mr_mime.png image parsed.
# ./icon\mudbray.png image parsed.
# ./icon\mudkip.png image parsed.
# ./icon\mudsdale.png image parsed.
# ./icon\muk.png image parsed.
# ./icon\munchlax.png image parsed.
# ./icon\munna.png image parsed.
# ./icon\murkrow.png image parsed.
# ./icon\musharna.png image parsed.
# ./icon\naganadel.png image parsed.
# ./icon\natu.png image parsed.
# ./icon\necrozma.png image parsed.
# ./icon\nidoking.png image parsed.
# ./icon\nidoqueen.png image parsed.
# ./icon\nidoran_f.png image parsed.
# ./icon\nidoran_m.png image parsed.
# ./icon\nidorina.png image parsed.
# ./icon\nidorino.png image parsed.
# ./icon\nihilego.png image parsed.
# ./icon\nincada.png image parsed.
# ./icon\ninetales.png image parsed.
# ./icon\ninjask.png image parsed.
# ./icon\noctowl.png image parsed.
# ./icon\noibat.png image parsed.
# ./icon\noivern.png image parsed.
# ./icon\nosepass.png image parsed.
# ./icon\numel.png image parsed.
# ./icon\nuzleaf.png image parsed.
# ./icon\octillery.png image parsed.
# ./icon\oddish.png image parsed.
# ./icon\omanyte.png image parsed.
# ./icon\omastar.png image parsed.
# ./icon\onix.png image parsed.
# ./icon\oranguru.png image parsed.
# ./icon\oricorio.png image parsed.
# ./icon\oshawott.png image parsed.
# ./icon\pachirisu.png image parsed.
# ./icon\palkia.png image parsed.
# ./icon\palossand.png image parsed.
# ./icon\palpitoad.png image parsed.
# ./icon\pancham.png image parsed.
# ./icon\pangoro.png image parsed.
# ./icon\panpour.png image parsed.
# ./icon\pansage.png image parsed.
# ./icon\pansear.png image parsed.
# ./icon\paras.png image parsed.
# ./icon\parasect.png image parsed.
# ./icon\passimian.png image parsed.
# ./icon\patrat.png image parsed.
# ./icon\pawniard.png image parsed.
# ./icon\pelipper.png image parsed.
# ./icon\persian.png image parsed.
# ./icon\petilil.png image parsed.
# ./icon\phanpy.png image parsed.
# ./icon\phantump.png image parsed.
# ./icon\pheromosa.png image parsed.
# ./icon\phione.png image parsed.
# ./icon\pichu.png image parsed.
# ./icon\pidgeot.png image parsed.
# ./icon\pidgeotto.png image parsed.
# ./icon\pidgey.png image parsed.
# ./icon\pidove.png image parsed.
# ./icon\pignite.png image parsed.
# ./icon\pikachu.png image parsed.
# ./icon\pikipek.png image parsed.
# ./icon\piloswine.png image parsed.
# ./icon\pineco.png image parsed.
# ./icon\pinsir.png image parsed.
# ./icon\piplup.png image parsed.
# ./icon\plusle.png image parsed.
# ./icon\poipole.png image parsed.
# ./icon\politoed.png image parsed.
# ./icon\poliwag.png image parsed.
# ./icon\poliwhirl.png image parsed.
# ./icon\poliwrath.png image parsed.
# ./icon\ponyta.png image parsed.
# ./icon\poochyena.png image parsed.
# ./icon\popplio.png image parsed.
# ./icon\porygon.png image parsed.
# ./icon\porygon2.png image parsed.
# ./icon\porygon_z.png image parsed.
# ./icon\primal_groudon.png image parsed.
# ./icon\primal_kyogre.png image parsed.
# ./icon\primarina.png image parsed.
# ./icon\primeape.png image parsed.
# ./icon\prinplup.png image parsed.
# ./icon\probopass.png image parsed.
# ./icon\psyduck.png image parsed.
# ./icon\pumpkaboo.png image parsed.
# ./icon\pupitar.png image parsed.
# ./icon\purrloin.png image parsed.
# ./icon\purugly.png image parsed.
# ./icon\pyroar.png image parsed.
# ./icon\pyukumuku.png image parsed.
# ./icon\quagsire.png image parsed.
# ./icon\question_mark.png image parsed.
# ./icon\quilava.png image parsed.
# ./icon\quilladin.png image parsed.
# ./icon\qwilfish.png image parsed.
# ./icon\raichu.png image parsed.
# ./icon\raikou.png image parsed.
# ./icon\ralts.png image parsed.
# ./icon\rampardos.png image parsed.
# ./icon\rapidash.png image parsed.
# ./icon\raticate.png image parsed.
# ./icon\rattata.png image parsed.
# ./icon\rayquaza.png image parsed.
# ./icon\regice.png image parsed.
# ./icon\regigigas.png image parsed.
# ./icon\regirock.png image parsed.
# ./icon\registeel.png image parsed.
# ./icon\relicanth.png image parsed.
# ./icon\remoraid.png image parsed.
# ./icon\reshiram.png image parsed.
# ./icon\reuniclus.png image parsed.
# ./icon\rhydon.png image parsed.
# ./icon\rhyhorn.png image parsed.
# ./icon\rhyperior.png image parsed.
# ./icon\ribombee.png image parsed.
# ./icon\riolu.png image parsed.
# ./icon\rockruff.png image parsed.
# ./icon\roggenrola.png image parsed.
# ./icon\roselia.png image parsed.
# ./icon\roserade.png image parsed.
# ./icon\rotom.png image parsed.
# ./icon\rowlet.png image parsed.
# ./icon\rufflet.png image parsed.
# ./icon\sableye.png image parsed.
# ./icon\salamence.png image parsed.
# ./icon\salandit.png image parsed.
# ./icon\salazzle.png image parsed.
# ./icon\samurott.png image parsed.
# ./icon\sandile.png image parsed.
# ./icon\sandshrew.png image parsed.
# ./icon\sandslash.png image parsed.
# ./icon\sandygast.png image parsed.
# ./icon\sawk.png image parsed.
# ./icon\sawsbuck.png image parsed.
# ./icon\scatterbug.png image parsed.
# ./icon\sceptile.png image parsed.
# ./icon\scizor.png image parsed.
# ./icon\scolipede.png image parsed.
# ./icon\scrafty.png image parsed.
# ./icon\scraggy.png image parsed.
# ./icon\scyther.png image parsed.
# ./icon\seadra.png image parsed.
# ./icon\seaking.png image parsed.
# ./icon\sealeo.png image parsed.
# ./icon\seedot.png image parsed.
# ./icon\seel.png image parsed.
# ./icon\seismitoad.png image parsed.
# ./icon\sentret.png image parsed.
# ./icon\serperior.png image parsed.
# ./icon\servine.png image parsed.
# ./icon\seviper.png image parsed.
# ./icon\sewaddle.png image parsed.
# ./icon\sharpedo.png image parsed.
# ./icon\shaymin.png image parsed.
# ./icon\shedinja.png image parsed.
# ./icon\shelgon.png image parsed.
# ./icon\shellder.png image parsed.
# ./icon\shellos.png image parsed.
# ./icon\shelmet.png image parsed.
# ./icon\shieldon.png image parsed.
# ./icon\shiftry.png image parsed.
# ./icon\shiinotic.png image parsed.
# ./icon\shinx.png image parsed.
# ./icon\shroomish.png image parsed.
# ./icon\shuckle.png image parsed.
# ./icon\shuppet.png image parsed.
# ./icon\sigilyph.png image parsed.
# ./icon\silcoon.png image parsed.
# ./icon\silvally.png image parsed.
# ./icon\simipour.png image parsed.
# ./icon\simisage.png image parsed.
# ./icon\simisear.png image parsed.
# ./icon\skarmory.png image parsed.
# ./icon\skiddo.png image parsed.
# ./icon\skiploom.png image parsed.
# ./icon\skitty.png image parsed.
# ./icon\skorupi.png image parsed.
# ./icon\skrelp.png image parsed.
# ./icon\skuntank.png image parsed.
# ./icon\slaking.png image parsed.
# ./icon\slakoth.png image parsed.
# ./icon\sliggoo.png image parsed.
# ./icon\slowbro.png image parsed.
# ./icon\slowking.png image parsed.
# ./icon\slowpoke.png image parsed.
# ./icon\slugma.png image parsed.
# ./icon\slurpuff.png image parsed.
# ./icon\smeargle.png image parsed.
# ./icon\smoochum.png image parsed.
# ./icon\sneasel.png image parsed.
# ./icon\snivy.png image parsed.
# ./icon\snorlax.png image parsed.
# ./icon\snorunt.png image parsed.
# ./icon\snover.png image parsed.
# ./icon\snubbull.png image parsed.
# ./icon\solgaleo.png image parsed.
# ./icon\solosis.png image parsed.
# ./icon\solrock.png image parsed.
# ./icon\spearow.png image parsed.
# ./icon\spewpa.png image parsed.
# ./icon\spheal.png image parsed.
# ./icon\spinarak.png image parsed.
# ./icon\spinda.png image parsed.
# ./icon\spiritomb.png image parsed.
# ./icon\spoink.png image parsed.
# ./icon\spritzee.png image parsed.
# ./icon\squirtle.png image parsed.
# ./icon\stakataka.png image parsed.
# ./icon\stantler.png image parsed.
# ./icon\staraptor.png image parsed.
# ./icon\staravia.png image parsed.
# ./icon\starly.png image parsed.
# ./icon\starmie.png image parsed.
# ./icon\staryu.png image parsed.
# ./icon\steelix.png image parsed.
# ./icon\steenee.png image parsed.
# ./icon\stoutland.png image parsed.
# ./icon\stufful.png image parsed.
# ./icon\stunfisk.png image parsed.
# ./icon\stunky.png image parsed.
# ./icon\sudowoodo.png image parsed.
# ./icon\suicune.png image parsed.
# ./icon\sunflora.png image parsed.
# ./icon\sunkern.png image parsed.
# ./icon\surskit.png image parsed.
# ./icon\swablu.png image parsed.
# ./icon\swadloon.png image parsed.
# ./icon\swalot.png image parsed.
# ./icon\swampert.png image parsed.
# ./icon\swanna.png image parsed.
# ./icon\swellow.png image parsed.
# ./icon\swinub.png image parsed.
# ./icon\swirlix.png image parsed.
# ./icon\swoobat.png image parsed.
# ./icon\sylveon.png image parsed.
# ./icon\taillow.png image parsed.
# ./icon\talonflame.png image parsed.
# ./icon\tangela.png image parsed.
# ./icon\tangrowth.png image parsed.
# ./icon\tapu_bulu.png image parsed.
# ./icon\tapu_fini.png image parsed.
# ./icon\tapu_koko.png image parsed.
# ./icon\tapu_lele.png image parsed.
# ./icon\tauros.png image parsed.
# ./icon\teddiursa.png image parsed.
# ./icon\tentacool.png image parsed.
# ./icon\tentacruel.png image parsed.
# ./icon\tepig.png image parsed.
# ./icon\terrakion.png image parsed.
# ./icon\throh.png image parsed.
# ./icon\thundurus.png image parsed.
# ./icon\timburr.png image parsed.
# ./icon\tirtouga.png image parsed.
# ./icon\togedemaru.png image parsed.
# ./icon\togekiss.png image parsed.
# ./icon\togepi.png image parsed.
# ./icon\togetic.png image parsed.
# ./icon\torchic.png image parsed.
# ./icon\torkoal.png image parsed.
# ./icon\tornadus.png image parsed.
# ./icon\torracat.png image parsed.
# ./icon\torterra.png image parsed.
# ./icon\totodile.png image parsed.
# ./icon\toucannon.png image parsed.
# ./icon\toxapex.png image parsed.
# ./icon\toxicroak.png image parsed.
# ./icon\tranquill.png image parsed.
# ./icon\trapinch.png image parsed.
# ./icon\treecko.png image parsed.
# ./icon\trevenant.png image parsed.
# ./icon\tropius.png image parsed.
# ./icon\trubbish.png image parsed.
# ./icon\trumbeak.png image parsed.
# ./icon\tsareena.png image parsed.
# ./icon\turtonator.png image parsed.
# ./icon\turtwig.png image parsed.
# ./icon\tympole.png image parsed.
# ./icon\tynamo.png image parsed.
# ./icon\type_null.png image parsed.
# ./icon\typhlosion.png image parsed.
# ./icon\tyranitar.png image parsed.
# ./icon\tyrantrum.png image parsed.
# ./icon\tyrogue.png image parsed.
# ./icon\tyrunt.png image parsed.
# ./icon\umbreon.png image parsed.
# ./icon\unfezant.png image parsed.
# ./icon\unown.png image parsed.
# ./icon\ursaring.png image parsed.
# ./icon\uxie.png image parsed.
# ./icon\vanillish.png image parsed.
# ./icon\vanillite.png image parsed.
# ./icon\vanilluxe.png image parsed.
# ./icon\vaporeon.png image parsed.
# ./icon\venipede.png image parsed.
# ./icon\venomoth.png image parsed.
# ./icon\venonat.png image parsed.
# ./icon\venusaur.png image parsed.
# ./icon\vespiquen.png image parsed.
# ./icon\vibrava.png image parsed.
# ./icon\victini.png image parsed.
# ./icon\victreebel.png image parsed.
# ./icon\vigoroth.png image parsed.
# ./icon\vikavolt.png image parsed.
# ./icon\vileplume.png image parsed.
# ./icon\virizion.png image parsed.
# ./icon\vivillon.png image parsed.
# ./icon\volbeat.png image parsed.
# ./icon\volcanion.png image parsed.
# ./icon\volcarona.png image parsed.
# ./icon\voltorb.png image parsed.
# ./icon\vullaby.png image parsed.
# ./icon\vulpix.png image parsed.
# ./icon\wailmer.png image parsed.
# ./icon\wailord.png image parsed.
# ./icon\walrein.png image parsed.
# ./icon\wartortle.png image parsed.
# ./icon\watchog.png image parsed.
# ./icon\weavile.png image parsed.
# ./icon\weedle.png image parsed.
# ./icon\weepinbell.png image parsed.
# ./icon\weezing.png image parsed.
# ./icon\whimsicott.png image parsed.
# ./icon\whirlipede.png image parsed.
# ./icon\whiscash.png image parsed.
# ./icon\whismur.png image parsed.
# ./icon\wigglytuff.png image parsed.
# ./icon\wimpod.png image parsed.
# ./icon\wingull.png image parsed.
# ./icon\wishiwashi.png image parsed.
# ./icon\wobbuffet.png image parsed.
# ./icon\woobat.png image parsed.
# ./icon\wooper.png image parsed.
# ./icon\wormadam.png image parsed.
# ./icon\wurmple.png image parsed.
# ./icon\wynaut.png image parsed.
# ./icon\xatu.png image parsed.
# ./icon\xerneas.png image parsed.
# ./icon\xurkitree.png image parsed.
# ./icon\yamask.png image parsed.
# ./icon\yanma.png image parsed.
# ./icon\yanmega.png image parsed.
# ./icon\yungoos.png image parsed.
# ./icon\yveltal.png image parsed.
# ./icon\zangoose.png image parsed.
# ./icon\zapdos.png image parsed.
# ./icon\zebstrika.png image parsed.
# ./icon\zekrom.png image parsed.
# ./icon\zeraora.png image parsed.
# ./icon\zigzagoon.png image parsed.
# ./icon\zoroark.png image parsed.
# ./icon\zorua.png image parsed.
# ./icon\zubat.png image parsed.
# ./icon\zweilous.png image parsed.
# ./icon\zygarde.png image parsed.
# ./footprint\abomasnow.png image parsed.
# ./footprint\abra.png image parsed.
# ./footprint\absol.png image parsed.
# ./footprint\accelgor.png image parsed.
# ./footprint\aerodactyl.png image parsed.
# ./footprint\aggron.png image parsed.
# ./footprint\aipom.png image parsed.
# ./footprint\alakazam.png image parsed.
# ./footprint\alomomola.png image parsed.
# ./footprint\altaria.png image parsed.
# ./footprint\ambipom.png image parsed.
# ./footprint\amoonguss.png image parsed.
# ./footprint\ampharos.png image parsed.
# ./footprint\anorith.png image parsed.
# ./footprint\arbok.png image parsed.
# ./footprint\arcanine.png image parsed.
# ./footprint\arceus.png image parsed.
# ./footprint\archen.png image parsed.
# ./footprint\archeops.png image parsed.
# ./footprint\ariados.png image parsed.
# ./footprint\armaldo.png image parsed.
# ./footprint\aron.png image parsed.
# ./footprint\articuno.png image parsed.
# ./footprint\audino.png image parsed.
# ./footprint\axew.png image parsed.
# ./footprint\azelf.png image parsed.
# ./footprint\azumarill.png image parsed.
# ./footprint\azurill.png image parsed.
# ./footprint\bagon.png image parsed.
# ./footprint\baltoy.png image parsed.
# ./footprint\banette.png image parsed.
# ./footprint\barboach.png image parsed.
# ./footprint\basculin.png image parsed.
# ./footprint\bastiodon.png image parsed.
# ./footprint\bayleef.png image parsed.
# ./footprint\beartic.png image parsed.
# ./footprint\beautifly.png image parsed.
# ./footprint\beedrill.png image parsed.
# ./footprint\beheeyem.png image parsed.
# ./footprint\beldum.png image parsed.
# ./footprint\bellossom.png image parsed.
# ./footprint\bellsprout.png image parsed.
# ./footprint\bibarel.png image parsed.
# ./footprint\bidoof.png image parsed.
# ./footprint\bisharp.png image parsed.
# ./footprint\blastoise.png image parsed.
# ./footprint\blaziken.png image parsed.
# ./footprint\blissey.png image parsed.
# ./footprint\blitzle.png image parsed.
# ./footprint\boldore.png image parsed.
# ./footprint\bonsly.png image parsed.
# ./footprint\bouffalant.png image parsed.
# ./footprint\braviary.png image parsed.
# ./footprint\breloom.png image parsed.
# ./footprint\bronzong.png image parsed.
# ./footprint\bronzor.png image parsed.
# ./footprint\budew.png image parsed.
# ./footprint\buizel.png image parsed.
# ./footprint\bulbasaur.png image parsed.
# ./footprint\buneary.png image parsed.
# ./footprint\butterfree.png image parsed.
# ./footprint\cacnea.png image parsed.
# ./footprint\cacturne.png image parsed.
# ./footprint\camerupt.png image parsed.
# ./footprint\carnivine.png image parsed.
# ./footprint\carracosta.png image parsed.
# ./footprint\carvanha.png image parsed.
# ./footprint\cascoon.png image parsed.
# ./footprint\castform.png image parsed.
# ./footprint\caterpie.png image parsed.
# ./footprint\celebi.png image parsed.
# ./footprint\chandelure.png image parsed.
# ./footprint\chansey.png image parsed.
# ./footprint\charizard.png image parsed.
# ./footprint\charmander.png image parsed.
# ./footprint\charmeleon.png image parsed.
# ./footprint\chatot.png image parsed.
# ./footprint\cherrim.png image parsed.
# ./footprint\cherubi.png image parsed.
# ./footprint\chikorita.png image parsed.
# ./footprint\chimchar.png image parsed.
# ./footprint\chimecho.png image parsed.
# ./footprint\chinchou.png image parsed.
# ./footprint\chingling.png image parsed.
# ./footprint\cinccino.png image parsed.
# ./footprint\clamperl.png image parsed.
# ./footprint\claydol.png image parsed.
# ./footprint\clefable.png image parsed.
# ./footprint\clefairy.png image parsed.
# ./footprint\cleffa.png image parsed.
# ./footprint\cloyster.png image parsed.
# ./footprint\cobalion.png image parsed.
# ./footprint\cofagrigus.png image parsed.
# ./footprint\combee.png image parsed.
# ./footprint\combusken.png image parsed.
# ./footprint\conkeldurr.png image parsed.
# ./footprint\corphish.png image parsed.
# ./footprint\corsola.png image parsed.
# ./footprint\cottonee.png image parsed.
# ./footprint\cradily.png image parsed.
# ./footprint\cranidos.png image parsed.
# ./footprint\crawdaunt.png image parsed.
# ./footprint\cresselia.png image parsed.
# ./footprint\croagunk.png image parsed.
# ./footprint\crobat.png image parsed.
# ./footprint\croconaw.png image parsed.
# ./footprint\crustle.png image parsed.
# ./footprint\cryogonal.png image parsed.
# ./footprint\cubchoo.png image parsed.
# ./footprint\cubone.png image parsed.
# ./footprint\cyndaquil.png image parsed.
# ./footprint\darkrai.png image parsed.
# ./footprint\darmanitan.png image parsed.
# ./footprint\darumaka.png image parsed.
# ./footprint\deerling.png image parsed.
# ./footprint\deino.png image parsed.
# ./footprint\delcatty.png image parsed.
# ./footprint\delibird.png image parsed.
# ./footprint\deoxys.png image parsed.
# ./footprint\dewgong.png image parsed.
# ./footprint\dewott.png image parsed.
# ./footprint\dialga.png image parsed.
# ./footprint\diglett.png image parsed.
# ./footprint\ditto.png image parsed.
# ./footprint\dodrio.png image parsed.
# ./footprint\doduo.png image parsed.
# ./footprint\donphan.png image parsed.
# ./footprint\dragonair.png image parsed.
# ./footprint\dragonite.png image parsed.
# ./footprint\drapion.png image parsed.
# ./footprint\dratini.png image parsed.
# ./footprint\drifblim.png image parsed.
# ./footprint\drifloon.png image parsed.
# ./footprint\drilbur.png image parsed.
# ./footprint\drowzee.png image parsed.
# ./footprint\druddigon.png image parsed.
# ./footprint\ducklett.png image parsed.
# ./footprint\dugtrio.png image parsed.
# ./footprint\dunsparce.png image parsed.
# ./footprint\duosion.png image parsed.
# ./footprint\durant.png image parsed.
# ./footprint\dusclops.png image parsed.
# ./footprint\dusknoir.png image parsed.
# ./footprint\duskull.png image parsed.
# ./footprint\dustox.png image parsed.
# ./footprint\dwebble.png image parsed.
# ./footprint\eelektrik.png image parsed.
# ./footprint\eelektross.png image parsed.
# ./footprint\eevee.png image parsed.
# ./footprint\ekans.png image parsed.
# ./footprint\electabuzz.png image parsed.
# ./footprint\electivire.png image parsed.
# ./footprint\electrike.png image parsed.
# ./footprint\electrode.png image parsed.
# ./footprint\elekid.png image parsed.
# ./footprint\elgyem.png image parsed.
# ./footprint\emboar.png image parsed.
# ./footprint\emolga.png image parsed.
# ./footprint\empoleon.png image parsed.
# ./footprint\entei.png image parsed.
# ./footprint\escavalier.png image parsed.
# ./footprint\espeon.png image parsed.
# ./footprint\excadrill.png image parsed.
# ./footprint\exeggcute.png image parsed.
# ./footprint\exeggutor.png image parsed.
# ./footprint\exploud.png image parsed.
# ./footprint\farfetchd.png image parsed.
# ./footprint\fearow.png image parsed.
# ./footprint\feebas.png image parsed.
# ./footprint\feraligatr.png image parsed.
# ./footprint\ferroseed.png image parsed.
# ./footprint\ferrothorn.png image parsed.
# ./footprint\finneon.png image parsed.
# ./footprint\flaaffy.png image parsed.
# ./footprint\flareon.png image parsed.
# ./footprint\floatzel.png image parsed.
# ./footprint\flygon.png image parsed.
# ./footprint\foongus.png image parsed.
# ./footprint\forretress.png image parsed.
# ./footprint\fraxure.png image parsed.
# ./footprint\frillish.png image parsed.
# ./footprint\froslass.png image parsed.
# ./footprint\furret.png image parsed.
# ./footprint\gabite.png image parsed.
# ./footprint\gallade.png image parsed.
# ./footprint\galvantula.png image parsed.
# ./footprint\garbodor.png image parsed.
# ./footprint\garchomp.png image parsed.
# ./footprint\gardevoir.png image parsed.
# ./footprint\gastly.png image parsed.
# ./footprint\gastrodon.png image parsed.
# ./footprint\genesect.png image parsed.
# ./footprint\gengar.png image parsed.
# ./footprint\geodude.png image parsed.
# ./footprint\gible.png image parsed.
# ./footprint\gigalith.png image parsed.
# ./footprint\girafarig.png image parsed.
# ./footprint\giratina.png image parsed.
# ./footprint\glaceon.png image parsed.
# ./footprint\glalie.png image parsed.
# ./footprint\glameow.png image parsed.
# ./footprint\gligar.png image parsed.
# ./footprint\gliscor.png image parsed.
# ./footprint\gloom.png image parsed.
# ./footprint\golbat.png image parsed.
# ./footprint\goldeen.png image parsed.
# ./footprint\golduck.png image parsed.
# ./footprint\golem.png image parsed.
# ./footprint\golett.png image parsed.
# ./footprint\golurk.png image parsed.
# ./footprint\gorebyss.png image parsed.
# ./footprint\gothita.png image parsed.
# ./footprint\gothitelle.png image parsed.
# ./footprint\gothorita.png image parsed.
# ./footprint\granbull.png image parsed.
# ./footprint\graveler.png image parsed.
# ./footprint\grimer.png image parsed.
# ./footprint\grotle.png image parsed.
# ./footprint\groudon.png image parsed.
# ./footprint\grovyle.png image parsed.
# ./footprint\growlithe.png image parsed.
# ./footprint\grumpig.png image parsed.
# ./footprint\gulpin.png image parsed.
# ./footprint\gurdurr.png image parsed.
# ./footprint\gyarados.png image parsed.
# ./footprint\happiny.png image parsed.
# ./footprint\hariyama.png image parsed.
# ./footprint\haunter.png image parsed.
# ./footprint\haxorus.png image parsed.
# ./footprint\heatmor.png image parsed.
# ./footprint\heatran.png image parsed.
# ./footprint\heracross.png image parsed.
# ./footprint\herdier.png image parsed.
# ./footprint\hippopotas.png image parsed.
# ./footprint\hippowdon.png image parsed.
# ./footprint\hitmonchan.png image parsed.
# ./footprint\hitmonlee.png image parsed.
# ./footprint\hitmontop.png image parsed.
# ./footprint\honchkrow.png image parsed.
# ./footprint\hoothoot.png image parsed.
# ./footprint\hoppip.png image parsed.
# ./footprint\horsea.png image parsed.
# ./footprint\houndoom.png image parsed.
# ./footprint\houndour.png image parsed.
# ./footprint\ho_oh.png image parsed.
# ./footprint\huntail.png image parsed.
# ./footprint\hydreigon.png image parsed.
# ./footprint\hypno.png image parsed.
# ./footprint\igglybuff.png image parsed.
# ./footprint\illumise.png image parsed.
# ./footprint\infernape.png image parsed.
# ./footprint\ivysaur.png image parsed.
# ./footprint\jellicent.png image parsed.
# ./footprint\jigglypuff.png image parsed.
# ./footprint\jirachi.png image parsed.
# ./footprint\jolteon.png image parsed.
# ./footprint\joltik.png image parsed.
# ./footprint\jumpluff.png image parsed.
# ./footprint\jynx.png image parsed.
# ./footprint\kabuto.png image parsed.
# ./footprint\kabutops.png image parsed.
# ./footprint\kadabra.png image parsed.
# ./footprint\kakuna.png image parsed.
# ./footprint\kangaskhan.png image parsed.
# ./footprint\karrablast.png image parsed.
# ./footprint\kecleon.png image parsed.
# ./footprint\keldeo.png image parsed.
# ./footprint\kingdra.png image parsed.
# ./footprint\kingler.png image parsed.
# ./footprint\kirlia.png image parsed.
# ./footprint\klang.png image parsed.
# ./footprint\klink.png image parsed.
# ./footprint\klinklang.png image parsed.
# ./footprint\koffing.png image parsed.
# ./footprint\krabby.png image parsed.
# ./footprint\kricketot.png image parsed.
# ./footprint\kricketune.png image parsed.
# ./footprint\krokorok.png image parsed.
# ./footprint\krookodile.png image parsed.
# ./footprint\kyogre.png image parsed.
# ./footprint\kyurem.png image parsed.
# ./footprint\lairon.png image parsed.
# ./footprint\lampent.png image parsed.
# ./footprint\landorus.png image parsed.
# ./footprint\lanturn.png image parsed.
# ./footprint\lapras.png image parsed.
# ./footprint\larvesta.png image parsed.
# ./footprint\larvitar.png image parsed.
# ./footprint\latias.png image parsed.
# ./footprint\latios.png image parsed.
# ./footprint\leafeon.png image parsed.
# ./footprint\leavanny.png image parsed.
# ./footprint\ledian.png image parsed.
# ./footprint\ledyba.png image parsed.
# ./footprint\lickilicky.png image parsed.
# ./footprint\lickitung.png image parsed.
# ./footprint\liepard.png image parsed.
# ./footprint\lileep.png image parsed.
# ./footprint\lilligant.png image parsed.
# ./footprint\lillipup.png image parsed.
# ./footprint\linoone.png image parsed.
# ./footprint\litwick.png image parsed.
# ./footprint\lombre.png image parsed.
# ./footprint\lopunny.png image parsed.
# ./footprint\lotad.png image parsed.
# ./footprint\loudred.png image parsed.
# ./footprint\lucario.png image parsed.
# ./footprint\ludicolo.png image parsed.
# ./footprint\lugia.png image parsed.
# ./footprint\lumineon.png image parsed.
# ./footprint\lunatone.png image parsed.
# ./footprint\luvdisc.png image parsed.
# ./footprint\luxio.png image parsed.
# ./footprint\luxray.png image parsed.
# ./footprint\machamp.png image parsed.
# ./footprint\machoke.png image parsed.
# ./footprint\machop.png image parsed.
# ./footprint\magby.png image parsed.
# ./footprint\magcargo.png image parsed.
# ./footprint\magikarp.png image parsed.
# ./footprint\magmar.png image parsed.
# ./footprint\magmortar.png image parsed.
# ./footprint\magnemite.png image parsed.
# ./footprint\magneton.png image parsed.
# ./footprint\magnezone.png image parsed.
# ./footprint\makuhita.png image parsed.
# ./footprint\mamoswine.png image parsed.
# ./footprint\manaphy.png image parsed.
# ./footprint\mandibuzz.png image parsed.
# ./footprint\manectric.png image parsed.
# ./footprint\mankey.png image parsed.
# ./footprint\mantine.png image parsed.
# ./footprint\mantyke.png image parsed.
# ./footprint\maractus.png image parsed.
# ./footprint\mareep.png image parsed.
# ./footprint\marill.png image parsed.
# ./footprint\marowak.png image parsed.
# ./footprint\marshtomp.png image parsed.
# ./footprint\masquerain.png image parsed.
# ./footprint\mawile.png image parsed.
# ./footprint\medicham.png image parsed.
# ./footprint\meditite.png image parsed.
# ./footprint\meganium.png image parsed.
# ./footprint\meloetta.png image parsed.
# ./footprint\meowth.png image parsed.
# ./footprint\mesprit.png image parsed.
# ./footprint\metagross.png image parsed.
# ./footprint\metang.png image parsed.
# ./footprint\metapod.png image parsed.
# ./footprint\mew.png image parsed.
# ./footprint\mewtwo.png image parsed.
# ./footprint\mienfoo.png image parsed.
# ./footprint\mienshao.png image parsed.
# ./footprint\mightyena.png image parsed.
# ./footprint\milotic.png image parsed.
# ./footprint\miltank.png image parsed.
# ./footprint\mime_jr.png image parsed.
# ./footprint\minccino.png image parsed.
# ./footprint\minun.png image parsed.
# ./footprint\misdreavus.png image parsed.
# ./footprint\mismagius.png image parsed.
# ./footprint\moltres.png image parsed.
# ./footprint\monferno.png image parsed.
# ./footprint\mothim.png image parsed.
# ./footprint\mr_mime.png image parsed.
# ./footprint\mudkip.png image parsed.
# ./footprint\muk.png image parsed.
# ./footprint\munchlax.png image parsed.
# ./footprint\munna.png image parsed.
# ./footprint\murkrow.png image parsed.
# ./footprint\musharna.png image parsed.
# ./footprint\natu.png image parsed.
# ./footprint\nidoking.png image parsed.
# ./footprint\nidoqueen.png image parsed.
# ./footprint\nidoran_f.png image parsed.
# ./footprint\nidoran_m.png image parsed.
# ./footprint\nidorina.png image parsed.
# ./footprint\nidorino.png image parsed.
# ./footprint\nincada.png image parsed.
# ./footprint\ninetales.png image parsed.
# ./footprint\ninjask.png image parsed.
# ./footprint\noctowl.png image parsed.
# ./footprint\nosepass.png image parsed.
# ./footprint\numel.png image parsed.
# ./footprint\nuzleaf.png image parsed.
# ./footprint\octillery.png image parsed.
# ./footprint\oddish.png image parsed.
# ./footprint\omanyte.png image parsed.
# ./footprint\omastar.png image parsed.
# ./footprint\onix.png image parsed.
# ./footprint\oshawott.png image parsed.
# ./footprint\pachirisu.png image parsed.
# ./footprint\palkia.png image parsed.
# ./footprint\palpitoad.png image parsed.
# ./footprint\panpour.png image parsed.
# ./footprint\pansage.png image parsed.
# ./footprint\pansear.png image parsed.
# ./footprint\paras.png image parsed.
# ./footprint\parasect.png image parsed.
# ./footprint\patrat.png image parsed.
# ./footprint\pawniard.png image parsed.
# ./footprint\pelipper.png image parsed.
# ./footprint\persian.png image parsed.
# ./footprint\petilil.png image parsed.
# ./footprint\phanpy.png image parsed.
# ./footprint\phione.png image parsed.
# ./footprint\pichu.png image parsed.
# ./footprint\pidgeot.png image parsed.
# ./footprint\pidgeotto.png image parsed.
# ./footprint\pidgey.png image parsed.
# ./footprint\pidove.png image parsed.
# ./footprint\pignite.png image parsed.
# ./footprint\pikachu.png image parsed.
# ./footprint\piloswine.png image parsed.
# ./footprint\pineco.png image parsed.
# ./footprint\pinsir.png image parsed.
# ./footprint\piplup.png image parsed.
# ./footprint\plusle.png image parsed.
# ./footprint\politoed.png image parsed.
# ./footprint\poliwag.png image parsed.
# ./footprint\poliwhirl.png image parsed.
# ./footprint\poliwrath.png image parsed.
# ./footprint\ponyta.png image parsed.
# ./footprint\poochyena.png image parsed.
# ./footprint\porygon.png image parsed.
# ./footprint\porygon2.png image parsed.
# ./footprint\porygon_z.png image parsed.
# ./footprint\primeape.png image parsed.
# ./footprint\prinplup.png image parsed.
# ./footprint\probopass.png image parsed.
# ./footprint\psyduck.png image parsed.
# ./footprint\pupitar.png image parsed.
# ./footprint\purrloin.png image parsed.
# ./footprint\purugly.png image parsed.
# ./footprint\quagsire.png image parsed.
# ./footprint\question_mark.png image parsed.
# ./footprint\quilava.png image parsed.
# ./footprint\qwilfish.png image parsed.
# ./footprint\raichu.png image parsed.
# ./footprint\raikou.png image parsed.
# ./footprint\ralts.png image parsed.
# ./footprint\rampardos.png image parsed.
# ./footprint\rapidash.png image parsed.
# ./footprint\raticate.png image parsed.
# ./footprint\rattata.png image parsed.
# ./footprint\rayquaza.png image parsed.
# ./footprint\regice.png image parsed.
# ./footprint\regigigas.png image parsed.
# ./footprint\regirock.png image parsed.
# ./footprint\registeel.png image parsed.
# ./footprint\relicanth.png image parsed.
# ./footprint\remoraid.png image parsed.
# ./footprint\reshiram.png image parsed.
# ./footprint\reuniclus.png image parsed.
# ./footprint\rhydon.png image parsed.
# ./footprint\rhyhorn.png image parsed.
# ./footprint\rhyperior.png image parsed.
# ./footprint\riolu.png image parsed.
# ./footprint\roggenrola.png image parsed.
# ./footprint\roselia.png image parsed.
# ./footprint\roserade.png image parsed.
# ./footprint\rufflet.png image parsed.
# ./footprint\sableye.png image parsed.
# ./footprint\salamence.png image parsed.
# ./footprint\samurott.png image parsed.
# ./footprint\sandile.png image parsed.
# ./footprint\sandshrew.png image parsed.
# ./footprint\sandslash.png image parsed.
# ./footprint\sawk.png image parsed.
# ./footprint\sawsbuck.png image parsed.
# ./footprint\sceptile.png image parsed.
# ./footprint\scizor.png image parsed.
# ./footprint\scolipede.png image parsed.
# ./footprint\scrafty.png image parsed.
# ./footprint\scraggy.png image parsed.
# ./footprint\scyther.png image parsed.
# ./footprint\seadra.png image parsed.
# ./footprint\seaking.png image parsed.
# ./footprint\sealeo.png image parsed.
# ./footprint\seedot.png image parsed.
# ./footprint\seel.png image parsed.
# ./footprint\seismitoad.png image parsed.
# ./footprint\sentret.png image parsed.
# ./footprint\serperior.png image parsed.
# ./footprint\servine.png image parsed.
# ./footprint\seviper.png image parsed.
# ./footprint\sewaddle.png image parsed.
# ./footprint\sharpedo.png image parsed.
# ./footprint\shaymin.png image parsed.
# ./footprint\shedinja.png image parsed.
# ./footprint\shelgon.png image parsed.
# ./footprint\shellder.png image parsed.
# ./footprint\shellos.png image parsed.
# ./footprint\shelmet.png image parsed.
# ./footprint\shieldon.png image parsed.
# ./footprint\shiftry.png image parsed.
# ./footprint\shinx.png image parsed.
# ./footprint\shroomish.png image parsed.
# ./footprint\shuckle.png image parsed.
# ./footprint\shuppet.png image parsed.
# ./footprint\sigilyph.png image parsed.
# ./footprint\silcoon.png image parsed.
# ./footprint\simipour.png image parsed.
# ./footprint\simisage.png image parsed.
# ./footprint\simisear.png image parsed.
# ./footprint\skarmory.png image parsed.
# ./footprint\skiploom.png image parsed.
# ./footprint\skitty.png image parsed.
# ./footprint\skorupi.png image parsed.
# ./footprint\skuntank.png image parsed.
# ./footprint\slaking.png image parsed.
# ./footprint\slakoth.png image parsed.
# ./footprint\slowbro.png image parsed.
# ./footprint\slowking.png image parsed.
# ./footprint\slowpoke.png image parsed.
# ./footprint\slugma.png image parsed.
# ./footprint\smeargle.png image parsed.
# ./footprint\smoochum.png image parsed.
# ./footprint\sneasel.png image parsed.
# ./footprint\snivy.png image parsed.
# ./footprint\snorlax.png image parsed.
# ./footprint\snorunt.png image parsed.
# ./footprint\snover.png image parsed.
# ./footprint\snubbull.png image parsed.
# ./footprint\solosis.png image parsed.
# ./footprint\solrock.png image parsed.
# ./footprint\spearow.png image parsed.
# ./footprint\spheal.png image parsed.
# ./footprint\spinarak.png image parsed.
# ./footprint\spinda.png image parsed.
# ./footprint\spiritomb.png image parsed.
# ./footprint\spoink.png image parsed.
# ./footprint\squirtle.png image parsed.
# ./footprint\stantler.png image parsed.
# ./footprint\staraptor.png image parsed.
# ./footprint\staravia.png image parsed.
# ./footprint\starly.png image parsed.
# ./footprint\starmie.png image parsed.
# ./footprint\staryu.png image parsed.
# ./footprint\steelix.png image parsed.
# ./footprint\stoutland.png image parsed.
# ./footprint\stunfisk.png image parsed.
# ./footprint\stunky.png image parsed.
# ./footprint\sudowoodo.png image parsed.
# ./footprint\suicune.png image parsed.
# ./footprint\sunflora.png image parsed.
# ./footprint\sunkern.png image parsed.
# ./footprint\surskit.png image parsed.
# ./footprint\swablu.png image parsed.
# ./footprint\swadloon.png image parsed.
# ./footprint\swalot.png image parsed.
# ./footprint\swampert.png image parsed.
# ./footprint\swanna.png image parsed.
# ./footprint\swellow.png image parsed.
# ./footprint\swinub.png image parsed.
# ./footprint\swoobat.png image parsed.
# ./footprint\taillow.png image parsed.
# ./footprint\tangela.png image parsed.
# ./footprint\tangrowth.png image parsed.
# ./footprint\tauros.png image parsed.
# ./footprint\teddiursa.png image parsed.
# ./footprint\tentacool.png image parsed.
# ./footprint\tentacruel.png image parsed.
# ./footprint\tepig.png image parsed.
# ./footprint\terrakion.png image parsed.
# ./footprint\throh.png image parsed.
# ./footprint\thundurus.png image parsed.
# ./footprint\timburr.png image parsed.
# ./footprint\tirtouga.png image parsed.
# ./footprint\togekiss.png image parsed.
# ./footprint\togepi.png image parsed.
# ./footprint\togetic.png image parsed.
# ./footprint\torchic.png image parsed.
# ./footprint\torkoal.png image parsed.
# ./footprint\tornadus.png image parsed.
# ./footprint\torterra.png image parsed.
# ./footprint\totodile.png image parsed.
# ./footprint\toxicroak.png image parsed.
# ./footprint\tranquill.png image parsed.
# ./footprint\trapinch.png image parsed.
# ./footprint\treecko.png image parsed.
# ./footprint\tropius.png image parsed.
# ./footprint\trubbish.png image parsed.
# ./footprint\turtwig.png image parsed.
# ./footprint\tympole.png image parsed.
# ./footprint\tynamo.png image parsed.
# ./footprint\typhlosion.png image parsed.
# ./footprint\tyranitar.png image parsed.
# ./footprint\tyrogue.png image parsed.
# ./footprint\umbreon.png image parsed.
# ./footprint\unfezant.png image parsed.
# ./footprint\unown.png image parsed.
# ./footprint\ursaring.png image parsed.
# ./footprint\uxie.png image parsed.
# ./footprint\vanillish.png image parsed.
# ./footprint\vanillite.png image parsed.
# ./footprint\vanilluxe.png image parsed.
# ./footprint\vaporeon.png image parsed.
# ./footprint\venipede.png image parsed.
# ./footprint\venomoth.png image parsed.
# ./footprint\venonat.png image parsed.
# ./footprint\venusaur.png image parsed.
# ./footprint\vespiquen.png image parsed.
# ./footprint\vibrava.png image parsed.
# ./footprint\victini.png image parsed.
# ./footprint\victreebel.png image parsed.
# ./footprint\vigoroth.png image parsed.
# ./footprint\vileplume.png image parsed.
# ./footprint\virizion.png image parsed.
# ./footprint\volbeat.png image parsed.
# ./footprint\volcarona.png image parsed.
# ./footprint\voltorb.png image parsed.
# ./footprint\vullaby.png image parsed.
# ./footprint\vulpix.png image parsed.
# ./footprint\wailmer.png image parsed.
# ./footprint\wailord.png image parsed.
# ./footprint\walrein.png image parsed.
# ./footprint\wartortle.png image parsed.
# ./footprint\watchog.png image parsed.
# ./footprint\weavile.png image parsed.
# ./footprint\weedle.png image parsed.
# ./footprint\weepinbell.png image parsed.
# ./footprint\weezing.png image parsed.
# ./footprint\whimsicott.png image parsed.
# ./footprint\whirlipede.png image parsed.
# ./footprint\whiscash.png image parsed.
# ./footprint\whismur.png image parsed.
# ./footprint\wigglytuff.png image parsed.
# ./footprint\wingull.png image parsed.
# ./footprint\wobbuffet.png image parsed.
# ./footprint\woobat.png image parsed.
# ./footprint\wooper.png image parsed.
# ./footprint\wurmple.png image parsed.
# ./footprint\wynaut.png image parsed.
# ./footprint\xatu.png image parsed.
# ./footprint\yamask.png image parsed.
# ./footprint\yanma.png image parsed.
# ./footprint\yanmega.png image parsed.
# ./footprint\zangoose.png image parsed.
# ./footprint\zapdos.png image parsed.
# ./footprint\zebstrika.png image parsed.
# ./footprint\zekrom.png image parsed.
# ./footprint\zigzagoon.png image parsed.
# ./footprint\zoroark.png image parsed.
# ./footprint\zorua.png image parsed.
# ./footprint\zubat.png image parsed.
# ./footprint\zweilous.png image parsed.
